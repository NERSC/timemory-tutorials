# %%
import hatchet as ht
import pandas as pd

import os, sys
from IPython.display import HTML, display

# %%
#load timemory data

gf = ht.GraphFrame.from_timemory('/global/cscratch1/sd/stephey/timemory-tutorials/tutorial-day-1/visualizing-and-analyzing-results/wall.tree.json')

lit_graph = gf.to_literal()

# %%
roundtrip_path = "/global/cscratch1/sd/stephey/hatchet/hatchet/external/roundtrip/"

# Add the path so that the notebook can find the Roundtrip extension
module_path = os.path.abspath(os.path.join(roundtrip_path)) 
if module_path not in sys.path:
    sys.path.append(module_path)
    
# Load the Roundtrip extension. This only needs to be loaded once.
# %load_ext roundtrip
# Out:
# <script>function cleanUp() { argList =[]; element = null; cell_idx = -1}</script>

# %%
gf = ht.GraphFrame.from_literal(lit_graph)
# %loadVisualization roundtrip_path lit_graph
# Out:
#                   <div id="roundtripTreeVis0"></div>
#                   <script>
#                   elementTop.appendChild(document.getElementById('roundtripTreeVis0'));
#                   element = document.getElementById('roundtripTreeVis0');//d3.v4
# (function (element) {
#     require(['https://d3js.org/d3.v4.min.js'], function (d3) {
#         var cleanTree = argList[0].replace(/'/g, '"');
#
#         var forestData = JSON.parse(cleanTree);
#
#         var rootNodeNames = [];
#         var numberOfTrees = forestData.length;
#         // Get the metric_column names
#         var metricColumns = d3.keys(forestData[0].metrics);
#         // pick the first metric listed to color the nodes
#         var selectedMetric = metricColumns[0];
#
#         forestMetrics = [];
#         forestMinMax = {};
#         for (var i = 0; i < numberOfTrees; i++) {
#             var thisTree = forestData[i];
#
#             // Get tree names for the display select options
#             rootNodeNames.push(thisTree.frame.name);
#
#             var thisTreeMetrics = {};
#             // init the min/max for all trees' metricColumns
#
#             for (var j = 0; j < metricColumns.length; j++) {
#                 thisTreeMetrics[metricColumns[j]] = {};
#                 thisTreeMetrics[metricColumns[j]]["min"] = Number.MAX_VALUE;
#                 thisTreeMetrics[metricColumns[j]]["max"] = 0;
#             }
#
#             forestMetrics.push(thisTreeMetrics);
#         }
#         for (var j = 0; j < metricColumns.length; j++) {
#             forestMinMax[metricColumns[j]] = {};
#             forestMinMax[metricColumns[j]]["min"] = Number.MAX_VALUE;
#             forestMinMax[metricColumns[j]]["max"] = 0;
#         }
#
#         rootNodeNames.push("Show all trees");
#
#         // ************** Generate the tree diagram  *****************
#         var margin = {top: 20, right: 20, bottom: 80, left: 20},
#                 treeHeight = 300,
#                 width = element.clientWidth - margin.right - margin.left,
#                 height = treeHeight * (numberOfTrees + 1),
#                 gOffset = [{x: margin.left, y: margin.top}]; //keep track of translations to know absolute position
#
#         d3.select(element).append('label').attr('for', 'metricSelect').text('Color by:');
#         var metricInput = d3.select(element).append("select") //element
#                 .attr("id", "metricSelect")
#                 .selectAll('option')
#                 .data(metricColumns)
#                 .enter()
#                 .append('option')
#                 .text(d => d)
#                 .attr('value', d => d);
#         document.getElementById("metricSelect").style.margin = "10px 10px 10px 0px";
#
#         d3.select(element).append('label').style('margin', '0 0 0 10px').attr('for', 'treeRootSelect').text(' Display:');
#         var treeRootInput = d3.select(element).append("select") //element
#                 .attr("id", "treeRootSelect")
#                 .selectAll('option')
#                 .data(rootNodeNames)
#                 .enter()
#                 .append('option')
#                 .attr('selected', d => d.name == 'Show all trees' ? true : false)
#                 .text(d => d)
#                 .attr('value', (d, i) => i + "|" + d);
#         document.getElementById("treeRootSelect").style.margin = "10px 10px 10px 10px";
#
#         var tooltip = d3.select(element).append("div")
#                 .attr('id', 'tooltip')
#                 .style('position', 'absolute')
#                 .style('top', '5px')
#                 .style('right', '15px')
#                 .style('padding', '5px')
#                 .style('border-radius', '5px')
#                 .style('background', '#ccc')
#                 .style('color', 'black')
#                 .style('font-size', '14px')
#                 .style('font-family', 'monospace')
#                 .html('<p>Click a node or "Select nodes" to see more info</p>');
#
#         var svg = d3.select(element).append("svg") //element
#                 .attr("width", width + margin.right + margin.left)
#                 .attr("height", height + margin.top + margin.bottom);
#
#         var brushOn = 1;
#         var colorScheme = 1; //default=1 : invert=-1
#         var button = svg.append('g')
#                 .attr('id', 'selectButton')
#                 .append('rect')
#                 .attr('width', '80px')
#                 .attr('height', '15px')
#                 .attr('x', 0).attr('y', 0).attr('rx', 5)
#                 .style('fill', '#ccc')
#                 .on('click', function () {
#                     brushOn = -1 * brushOn;
#                     activateBrush(brushOn);
#                 });
#         d3.select(element).select('#selectButton').append('text')
#                 .attr("x", 3)
#                 .attr("y", 12)
#                 .text('Select nodes')
#                 .attr("font-family", "sans-serif")
#                 .attr("font-size", "12px")
#                 .attr('cursor', 'pointer')
#                 .on('click', function () {
#                     brushOn = -1 * brushOn;
#                     activateBrush(brushOn);
#                 });
#         var colorButton = svg.append('g')
#                 .attr('id', 'colorButton')
#                 .append('rect')
#                 .attr('width', '90px')
#                 .attr('height', '15px')
#                 .attr('x', 90).attr('y', 0).attr('rx', 5)
#                 .style('fill', '#ccc');
#         d3.select(element).select('#colorButton').append('text')
#                 .attr("x", 93)
#                 .attr("y", 12)
#                 .text('Colors: default')
#                 .attr("font-family", "sans-serif")
#                 .attr("font-size", "12px")
#                 .attr('cursor', 'pointer')
#                 .on('click', function () {
#                     colorScheme = -1 * colorScheme;
#                     var curMetric = d3.select(element).select('#metricSelect').property('value');
#                     var curLegend = d3.select(element).select('#unifyLegends').text();
#                     d3.select(element).selectAll(".circleNode")
#                             .transition()
#                             .duration(duration)
#                             .style('fill', function (d) {
#                                 if (curLegend == 'Legends: unified') {
#                                     return colorScale(d.data.metrics[curMetric], -1);
#                                 }
#                                 return colorScale(d.data.metrics[curMetric], d.treeIndex);
#                             })
#                             .style('stroke', 'black');
#
#                     //Update each individual legend to inverted scale
#                     for (var treeIndex = 0; treeIndex < numberOfTrees; treeIndex++) {
#                         if (curLegend == 'Legends: unified') {
#                             setColorLegend(-1);
#                         } else {
#                             setColorLegend(treeIndex);
#                         }
#                     }
#                 });
#         var unifyLegends = svg.append('g')
#                 .attr('id', 'unifyLegends')
#                 .append('rect')
#                 .attr('width', '100px')
#                 .attr('height', '15px')
#                 .attr('x', 190)
#                 .attr('y', 0)
#                 .attr('rx', 5)
#                 .style('fill', '#ccc');
#         d3.select(element).select('#unifyLegends').append('text')
#                 .attr("x", 195)
#                 .attr("y", 12)
#                 .text('Legends: unified')
#                 .attr("font-family", "sans-serif")
#                 .attr("font-size", "12px")
#                 .attr('cursor', 'pointer')
#                 .on('click', function () {
#                     var curMetric = d3.select(element).select('#metricSelect').property('value');
#                     var sameLegend = true;
#                     if (d3.select(this).text() == 'Legends: unified') {
#                         d3.select(this).text('Legends: indiv.');
#                         sameLegend = false;
#                         for (var treeIndex = 0; treeIndex < numberOfTrees; treeIndex++) {
#                             set

# %%
gf.dataframe
# Out:
#                                                                              name  \
# node
# {'name': 'generate_history/outer-loop-0', 'type...  generate_history/outer-loop-0
# {'name': 'generate_history/inner-loop-0', 'type...  generate_history/inner-loop-0
# {'name': 'generate_history/consume', 'type': 'r...       generate_history/consume
# {'name': 'generate_history/do-sleep', 'type': '...      generate_history/do-sleep
# {'name': 'generate_history/inner-loop-1', 'type...  generate_history/inner-loop-1
# {'name': 'generate_history/consume', 'type': 'r...       generate_history/consume
# {'name': 'generate_history/do-sleep', 'type': '...      generate_history/do-sleep
# {'name': 'generate_history/outer-loop-0', 'type...  generate_history/outer-loop-0
# {'name': 'generate_history/inner-loop-0', 'type...  generate_history/inner-loop-0
# {'name': 'generate_history/consume', 'type': 'r...       generate_history/consume
# {'name': 'generate_history/do-sleep', 'type': '...      generate_history/do-sleep
# {'name': 'generate_history/inner-loop-1', 'type...  generate_history/inner-loop-1
# {'name': 'generate_history/consume', 'type': 'r...       generate_history/consume
# {'name': 'generate_history/do-sleep', 'type': '...      generate_history/do-sleep
# {'name': 'generate_history/outer-loop-1', 'type...  generate_history/outer-loop-1
# {'name': 'generate_history/inner-loop-0', 'type...  generate_history/inner-loop-0
# {'name': 'generate_history/consume', 'type': 'r...       generate_history/consume
# {'name': 'generate_history/do-sleep', 'type': '...      generate_history/do-sleep
# {'name': 'generate_history/inner-loop-1', 'type...  generate_history/inner-loop-1
# {'name': 'generate_history/consume', 'type': 'r...       generate_history/consume
# {'name': 'generate_history/do-sleep', 'type': '...      generate_history/do-sleep
# {'name': 'generate_history/outer-loop-1', 'type...  generate_history/outer-loop-1
# {'name': 'generate_history/inner-loop-0', 'type...  generate_history/inner-loop-0
# {'name': 'generate_history/consume', 'type': 'r...       generate_history/consume
# {'name': 'generate_history/do-sleep', 'type': '...      generate_history/do-sleep
# {'name': 'generate_history/inner-loop-1', 'type...  generate_history/inner-loop-1
# {'name': 'generate_history/consume', 'type': 'r...       generate_history/consume
# {'name': 'generate_history/do-sleep', 'type': '...      generate_history/do-sleep
#
#                                                          max   max.inc  \
# node
# {'name': 'generate_history/outer-loop-0', 'type...  6.057227  6.057227
# {'name': 'generate_history/inner-loop-0', 'type...  2.182733  2.182733
# {'name': 'generate_history/consume', 'type': 'r...  0.050016  0.050016
# {'name': 'generate_history/do-sleep', 'type': '...  0.050272  0.050272
# {'name': 'generate_history/inner-loop-1', 'type...  3.626376  3.626376
# {'name': 'generate_history/consume', 'type': 'r...  0.100040  0.100040
# {'name': 'generate_history/do-sleep', 'type': '...  0.100276  0.100276
# {'name': 'generate_history/outer-loop-0', 'type...  5.640813  5.640813
# {'name': 'generate_history/inner-loop-0', 'type...  2.032796  2.032796
# {'name': 'generate_history/consume', 'type': 'r...  0.050029  0.050029
# {'name': 'generate_history/do-sleep', 'type': '...  0.050248  0.050248
# {'name': 'generate_history/inner-loop-1', 'type...  3.432322  3.432322
# {'name': 'generate_history/consume', 'type': 'r...  0.100071  0.100071
# {'name': 'generate_history/do-sleep', 'type': '...  0.100295  0.100295
# {'name': 'generate_history/outer-loop-1', 'type...  5.916623  5.916623
# {'name': 'generate_history/inner-loop-0', 'type...  2.201737  2.201737
# {'name': 'generate_history/consume', 'type': 'r...  0.050015  0.050015
# {'name': 'generate_history/do-sleep', 'type': '...  0.050252  0.050252
# {'name': 'generate_history/inner-loop-1', 'type...  3.472788  3.472788
# {'name': 'generate_history/consume', 'type': 'r...  0.100024  0.100024
# {'name': 'generate_history/do-sleep', 'type': '...  0.100354  0.100354
# {'name': 'generate_history/outer-loop-1', 'type...  5.529476  5.529476
# {'name': 'generate_history/inner-loop-0', 'type...  1.953446  1.953446
# {'name': 'generate_history/consume', 'type': 'r...  0.050014  0.050014
# {'name': 'generate_history/do-sleep', 'type': '...  0.050349  0.050349
# {'name': 'generate_history/inner-loop-1', 'type...  3.380966  3.380966
# {'name': 'generate_history/consume', 'type': 'r...  0.100041  0.100041
# {'name': 'generate_history/do-sleep', 'type': '...  0.100269  0.100269
#
#                                                         mean  mean.inc  \
# node
# {'name': 'generate_history/outer-loop-0', 'type...  0.250264  5.939748
# {'name': 'generate_history/inner-loop-0', 'type...  2.014169  2.114387
# {'name': 'generate_history/consume', 'type': 'r...  0.050011  0.050011
# {'name': 'generate_history/do-sleep', 'type': '...  0.050206  0.050206
# {'name': 'generate_history/inner-loop-1', 'type...  3.374856  3.575097
# {'name': 'generate_history/consume', 'type': 'r...  0.100022  0.100022
# {'name': 'generate_history/do-sleep', 'type': '...  0.100219  0.100219
# {'name': 'generate_history/outer-loop-0', 'type...  0.250317  5.567252
# {'name': 'generate_history/inner-loop-0', 'type...  1.853055  1.953268
# {'name': 'generate_history/consume', 'type': 'r...  0.050018  0.050018
# {'name': 'generate_history/do-sleep', 'type': '...  0.050195  0.050195
# {'name': 'generate_history/inner-loop-1', 'type...  3.163399  3.363666
# {'name': 'generate_history/consume', 'type': 'r...  0.100029  0.100029
# {'name': 'generate_history/do-sleep', 'type': '...  0.100238  0.100238
# {'name': 'generate_history/outer-loop-1', 'type...  0.250265  5.749496
# {'name': 'generate_history/inner-loop-0', 'type...  2.026567  2.126799
# {'name': 'generate_history/consume', 'type': 'r...  0.050012  0.050012
# {'name': 'generate_history/do-sleep', 'type': '...  0.050221  0.050221
# {'name': 'generate_history/inner-loop-1', 'type...  3.172150  3.372432
# {'name': 'generate_history/consume', 'type': 'r...  0.100018  0.100018
# {'name': 'generate_history/do-sleep', 'type': '...  0.100263  0.100263
# {'name': 'generate_history/outer-loop-1', 'type...  0.250297  5.444206
# {'name': 'generate_history/inner-loop-0', 'type...  1.820627  1.920895
# {'name': 'generate_history/consume', 'type': 'r...  0.050012  0.050012
# {'name': 'generate_history/do-sleep', 'type': '...  0.050256  0.050256
# {'name': 'generate_history/inner-loop-1', 'type...  3.072769  3.273014
# {'name': 'generate_history/consume', 'type': 'r...  0.100024  0.100024
# {'name': 'generate_history/do-sleep', 'type': '...  0.100221  0.100221
#
#                                                          min   min.inc  \
# node
# {'name': 'generate_history/outer-loop-0', 'type...  1.982643  5.803667
# {'name': 'generate_history/inner-loop-0', 'type...  0.050009  1.982643
# {'name': 'generate_history/consume', 'type': 'r...  0.050009  0.050009
# {'name': 'generate_history/do-sleep', 'type': '...  0.050135  0.050135
# {'name': 'generate_history/inner-loop-1', 'type...  0.100013  3.531919
# {'name': 'generate_history/consume', 'type': 'r...  0.100013  0.100013
# {'name': 'generate_history/do-sleep', 'type': '...  0.100143  0.100143
# {'name': 'generate_history/outer-loop-0', 'type...  1.832888  5.515562
# {'name': 'generate_history/inner-loop-0', 'type...  0.050011  1.832888
# {'name': 'generate_history/consume', 'type': 'r...  0.050011  0.050011
# {'name': 'generate_history/do-sleep', 'type': '...  0.050143  0.050143
# {'name': 'generate_history/inner-loop-1', 'type...  0.100009  3.329345
# {'name': 'generate_history/consume', 'type': 'r...  0.100009  0.100009
# {'name': 'generate_history/do-sleep', 'type': '...  0.100196  0.100196
# {'name': 'generate_history/outer-loop-1', 'type...  2.051024  5.577365
# {'name': 'generate_history/inner-loop-0', 'type...  0.050011  2.051024
# {'name': 'generate_history/consume', 'type': 'r...  0.050011  0.050011
# {'name': 'generate_history/do-sleep', 'type': '...  0.050193  0.050193
# {'name': 'generate_history/inner-loop-1', 'type...  0.100013  3.276063
# {'name': 'generate_history/consume', 'type': 'r...  0.100013  0.100013
# {'name': 'generate_history/do-sleep', 'type': '...  0.100166  0.100166
# {'name': 'generate_history/outer-loop-1', 'type...  1.886646  5.361095
# {'name': 'generate_history/inner-loop-0', 'type...  0.050010  1.886646
# {'name': 'generate_history/consume', 'type': 'r...  0.050010  0.050010
# {'name': 'generate_history/do-sleep', 'type': '...  0.050179  0.050179
# {'name': 'generate_history/inner-loop-1', 'type...  0.100011  3.164490
# {'name': 'generate_history/consume', 'type': 'r...  0.100011  0.100011
# {'name': 'generate_history/do-sleep', 'type': '...  0.100150  0.100150
#
#                                                            sqr     sqr.inc  \
# node
# {'name': 'generate_history/outer-loop-0', 'type...  108.178371  211.744145
# {'name': 'generate_history/inner-loop-0', 'type...   26.839117   26.869248
# {'name': 'generate_history/consume', 'type': 'r...    0.015007    0.015007
# {'name': 'generate_history/do-sleep', 'type': '...    0.015124    0.015124
# {'name': 'generate_history/inner-loop-1', 'type...   76.576236   76.696526
# {'name': 'generate_history/consume', 'type': 'r...    0.060027    0.060027
# {'name': 'generate_history/do-sleep', 'type': '...    0.060263    0.060263
# {'name': 'generate_history/outer-loop-0', 'type...   95.164175  185.979178
# {'name': 'generate_history/inner-loop-0', 'type...   22.892299   22.922427
# {'name': 'generate_history/consume', 'type': 'r...    0.015011    0.015011
# {'name': 'generate_history/do-sleep', 'type': '...    0.015117    0.015117
# {'name': 'generate_history/inner-loop-1', 'type...   67.772256   67.892576
# {'name': 'generate_history/consume', 'type': 'r...    0.060035    0.060035
# {'name': 'generate_history/do-sleep', 'type': '...    0.060286    0.060286
# {'name': 'generate_history/outer-loop-1', 'type...   68.693288  132.334610
# {'name': 'generate_history/inner-loop-0', 'type...   18.093163   18.113256
# {'name': 'generate_history/consume', 'type': 'r...    0.010005    0.010005
# {'name': 'generate_history/do-sleep', 'type': '...    0.010088    0.010088
# {'name': 'generate_history/inner-loop-1', 'type...   45.447841   45.528067
# {'name': 'generate_history/consume', 'type': 'r...    0.040015    0.040015
# {'name': 'generate_history/do-sleep', 'type': '...    0.040211    0.040211
# {'name': 'generate_history/outer-loop-1', 'type...   60.932600  118.582918
# {'name': 'generate_history/inner-loop-0', 'type...   14.741482   14.761590
# {'name': 'generate_history/consume', 'type': 'r...    0.010005    0.010005
# {'name': 'generate_history/do-sleep', 'type': '...    0.010103    0.010103
# {'name': 'generate_history/inner-loop-1', 'type...   42.808533   42.888729
# {'name': 'generate_history/consume', 'type': 'r...    0.040019    0.040019
# {'name': 'generate_history/do-sleep', 'type': '...    0.040177    0.040177
#
#                                                       stddev  stddev.inc  \
# node
# {'name': 'generate_history/outer-loop-0', 'type...  4.643330    0.110012
# {'name': 'generate_history/inner-loop-0', 'type...  0.706803    0.095357
# {'name': 'generate_history/consume', 'type': 'r...  0.000003    0.000003
# {'name': 'generate_history/do-sleep', 'type': '...  0.000053    0.000053
# {'name': 'generate_history/inner-loop-1', 'type...  1.283613    0.041493
# {'name': 'generate_history/consume', 'type': 'r...  0.000010    0.000010
# {'name': 'generate_history/do-sleep', 'type': '...  0.000060    0.000060
# {'name': 'generate_history/outer-loop-0', 'type...  4.354038    0.051830
# {'name': 'generate_history/inner-loop-0', 'type...  0.676670    0.078590
# {'name': 'generate_history/consume', 'type': 'r...  0.000008    0.000008
# {'name': 'generate_history/do-sleep', 'type': '...  0.000036    0.000036
# {'name': 'generate_history/inner-loop-1', 'type...  1.243357    0.037639
# {'name': 'generate_history/consume', 'type': 'r...  0.000022    0.000022
# {'name': 'generate_history/do-sleep', 'type': '...  0.000041    0.000041
# {'name': 'generate_history/outer-loop-1', 'type...  4.776427    0.189573
# {'name': 'generate_history/inner-loop-0', 'type...  0.745044    0.081968
# {'name': 'generate_history/consume', 'type': 'r...  0.000002    0.000002
# {'name': 'generate_history/do-sleep', 'type': '...  0.000027    0.000027
# {'name': 'generate_history/inner-loop-1', 'type...  1.316270    0.107842
# {'name': 'generate_history/consume', 'type': 'r...  0.000006    0.000006
# {'name': 'generate_history/do-sleep', 'type': '...  0.000078    0.000078
# {'name': 'generate_history/outer-loop-1', 'type...  4.497481    0.092041
# {'name': 'generate_history/inner-loop-0', 'type...  0.703030    0.027337
# {'name': 'generate_history/consume', 'type': 'r...  0.000002    0.000002
# {'name': 'generate_history/do-sleep', 'type': '...  0.000070    0.000070
# {'name': 'generate_history/inner-loop-1', 'type...  1.296264    0.112922
# {'name': 'generate_history/consume', 'type': 'r...  0.000013    0.000013
# {'name': 'generate_history/do-sleep', 'type': '...  0.000050    0.000050
#
#                                                           sum    sum.inc  \
# node
# {'name': 'generate_history/outer-loop-0', 'type...   1.501585  35.638488
# {'name': 'generate_history/inner-loop-0', 'type...  12.085015  12.686319
# {'name': 'generate_history/consume', 'type': 'r...   0.300066   0.300066
# {'name': 'generate_history/do-sleep', 'type': '...   0.301239   0.301239
# {'name': 'generate_history/inner-loop-1', 'type...  20.249136  21.450583
# {'name': 'generate_history/consume', 'type': 'r...   0.600134   0.600134
# {'name': 'generate_history/do-sleep', 'type': '...   0.601313   0.601313
# {'name': 'generate_history/outer-loop-0', 'type...   1.501904  33.403510
# {'name': 'generate_history/inner-loop-0', 'type...  11.118333  11.719611
# {'name': 'generate_history/consume', 'type': 'r...   0.300109   0.300109
# {'name': 'generate_history/do-sleep', 'type': '...   0.301169   0.301169
# {'name': 'generate_history/inner-loop-1', 'type...  18.980397  20.181996
# {'name': 'generate_history/consume', 'type': 'r...   0.600173   0.600173
# {'name': 'generate_history/do-sleep', 'type': '...   0.601426   0.601426
# {'name': 'generate_history/outer-loop-1', 'type...   1.001059  22.997982
# {'name': 'generate_history/inner-loop-0', 'type...   8.106267   8.507197
# {'name': 'generate_history/consume', 'type': 'r...   0.200048   0.200048
# {'name': 'generate_history/do-sleep', 'type': '...   0.200882   0.200882
# {'name': 'generate_history/inner-loop-1', 'type...  12.688600  13.489726
# {'name': 'generate_history/consume', 'type': 'r...   0.400073   0.400073
# {'name': 'generate_history/do-sleep', 'type': '...   0.401053   0.401053
# {'name': 'generate_history/outer-loop-1', 'type...   1.001189  21.776823
# {'name': 'generate_history/inner-loop-0', 'type...   7.282507   7.683579
# {'name': 'generate_history/consume', 'type': 'r...   0.200047   0.200047
# {'name': 'generate_history/do-sleep', 'type': '...   0.201025   0.201025
# {'name': 'generate_history/inner-loop-1', 'type...  12.291076  13.092055
# {'name': 'generate_history/consume', 'type': 'r...   0.400097   0.400097
# {'name': 'generate_history/do-sleep', 'type': '...   0.400883   0.400883
#
#                                                     _hatchet_nid
# node
# {'name': 'generate_history/outer-loop-0', 'type...             0
# {'name': 'generate_history/inner-loop-0', 'type...             1
# {'name': 'generate_history/consume', 'type': 'r...             2
# {'name': 'generate_history/do-sleep', 'type': '...             3
# {'name': 'generate_history/inner-loop-1', 'type...             4
# {'name': 'generate_history/consume', 'type': 'r...             5
# {'name': 'generate_history/do-sleep', 'type': '...             6
# {'name': 'generate_history/outer-loop-0', 'type...             7
# {'name': 'generate_history/inner-loop-0', 'type...             8
# {'name': 'generate_history/consume', 'type': 'r...             9
# {'name': 'generate_history/do-sleep', 'type': '...            10
# {'name': 'generate_history/inner-loop-1', 'type...            11
# {'name': 'generate_history/consume', 'type': 'r...            12
# {'name': 'generate_history/do-sleep', 'type': '...            13
# {'name': 'generate_history/outer-loop-1', 'type...            14
# {'name': 'generate_history/inner-loop-0', 'type...            15
# {'name': 'generate_history/consume', 'type': 'r...            16
# {'name': 'generate_history/do-sleep', 'type': '...            17
# {'name': 'generate_history/inner-loop-1', 'type...            18
# {'name': 'generate_history/consume', 'type': 'r...            19
# {'name': 'generate_history/do-sleep', 'type': '...            20
# {'name': 'generate_history/outer-loop-1', 'type...            21
# {'name': 'generate_history/inner-loop-0', 'type...            22
# {'name': 'generate_history/consume', 'type': 'r...            23
# {'name': 'generate_history/do-sleep', 'type': '...            24
# {'name': 'generate_history/inner-loop-1', 'type...            25
# {'name': 'generate_history/consume', 'type': 'r...            26
# {'name': 'generate_history/do-sleep', 'type': '...            27
